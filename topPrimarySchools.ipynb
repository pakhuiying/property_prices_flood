# %%
import numpy as np
import pandas as pd
import geopandas as gpd
import os
import re
import fnmatch
import matplotlib.pyplot as plt
from functools import reduce
from bs4 import BeautifulSoup
import requests
import osmnx as ox
from API_KEY import get_OneMap_token
import networkx as nx

# %% [markdown]
# # Proximity to primary schools
# - OneMap's SchoolQuery and [MOE's SchoolFinder](https://www.moe.gov.sg/schoolfinder) uses 1km and between 1-2km as thresholds to determine parent's priority in getting their child placement in a primary school.
# - The distance is not measured using euclidean distance, it is measured using SLA's OneMap SchoolQuery or MOE Distance Checker Tool.
# - Distance is calculated using the shortest path along the road network and footpaths.
# - As per OneMap's visualisation, I can confirm that the distance is not measured using euclidean distance

# %%
save_dir = os.path.join(os.getcwd(),"Data","Road_Networks")

# import car network
filename = "SG_car_network.graphml"
G_car = ox.load_graphml(os.path.join(save_dir,filename))

# import walking network
filename = "SG_walk_network.graphml"
G_walk = ox.load_graphml(os.path.join(save_dir, filename))

# %% [markdown]
# # Scrap top primary schools ranked from best to worst

# %%
URL = "https://www.creativecampus.com.sg/best-primary-schools-in-singapore-2024"
page = requests.get(URL)
# parse HTML
soup = BeautifulSoup(page.content, "html.parser")

# Find the table
table = soup.find('table', {'id': 'primary'})

# Extract all school names (first <td> of each <tr> in <tbody>)
school_names = [row.find_all('td')[0].text.strip() for row in table.find('tbody').find_all('tr')]

# Output the list
print(school_names)
# Out:
# ["Methodist Girls' School (Primary)", 'Tao Nan School', 'Ai Tong School', "Holy Innocents' Primary School", "CHIJ St. Nicholas Girls' School", 'Admiralty Primary School', "St. Joseph's Institution Junior", 'Catholic High School', 'Anglo-Chinese School (Junior)', 'Chongfu School', 'Kong Hwa School', "St. Hilda's Primary School", 'Anglo-Chinese School (Primary)', 'Nan Chiau Primary School', 'Nan Hua Primary School', 'Nanyang Primary School', 'Pei Hwa Presbyterian Primary School', 'Kuo Chuan Presbyterian Primary School', 'Rulang Primary School', "Singapore Chinese Girls' Primary School", 'Maris Stella High School', 'Fairfield Methodist School (Primary)', 'South View Primary School', 'CHIJ Primary (Toa Payoh)', 'Henry Park Primary School', 'Pei Chun Public School', 'Xinmin Primary School', 'Red Swastika School', "St. Anthony's Primary School", 'Rosyth School', "Paya Lebar Methodist Girls' School (Primary)", 'Northland Primary School', 'Pasir Ris Primary School', 'Mee Toh School', 'Radin Mas Primary School', 'CHIJ Our Lady Of The Nativity', 'Horizon Primary School', 'Sengkang Green Primary School', "Raffles Girls' Primary School", 'Maha Bodhi School', "St. Andrew's Junior School", 'Keming Primary School', 'Chua Chu Kang Primary School', 'River Valley Primary School', 'Anderson Primary School', 'Gongshang Primary School', 'Hong Wen School', 'Bukit Panjang Primary School', "St. Gabriel's Primary School", 'Frontier Primary School', 'Poi Ching School', 'CHIJ Our Lady Of Good Counsel', 'Canossa Catholic Primary School', 'Hougang Primary School', 'Westwood Primary School', 'Qifa Primary School', 'Temasek Primary School', 'Yu Neng Primary School', "St. Margaret's School (Primary)", 'Tanjong Katong Primary School', 'Canberra Primary School', 'Innova Primary School', 'Woodlands Primary School', 'Yangzheng Primary School', 'White Sands Primary School', 'Montfort Junior School', 'Rivervale Primary School', 'Compassvale Primary School', 'CHIJ (Katong) Primary', "St. Stephen's School", 'Shuqun Primary School', 'Chongzheng Primary School', 'CHIJ (Kellock)', 'CHIJ Our Lady Queen Of Peace', 'De La Salle School', 'Princess Elizabeth Primary School', 'Punggol Primary School', 'Punggol Green Primary School', 'Wellington Primary School', 'Woodgrove Primary School', 'Marymount Convent School', 'West Grove Primary School', 'Jurong West Primary School', 'Teck Ghee Primary School', 'Alexandra Primary School', 'Riverside Primary School', 'Ngee Ann Primary School', 'Qihua Primary School', 'Geylang Methodist School (Primary)', "St. Anthony's Canossian Primary School", 'Kheng Cheng School', 'Fern Green Primary School', 'Concord Primary School', 'Tampines Primary School', 'Telok Kurau Primary School', 'Townsville Primary School', 'Elias Park Primary School', 'Huamin Primary School', 'Valour Primary School', 'Endeavour Primary School', 'Jing Shan Primary School', 'Fengshan Primary School', 'Jiemin Primary School', 'Waterway Primary School', 'Punggol Cove Primary School', 'Zhangde Primary School', 'Naval Base Primary School', 'Sembawang Primary School', 'Opera Estate Primary School', 'Park View Primary School', 'Xishan Primary School', 'Fernvale Primary School', 'Zhonghua Primary School', 'Bukit Timah Primary School', 'Farrer Park Primary School', "Haig Girls' School", 'Greenwood Primary School', 'Palm View Primary School', 'Yew Tee Primary School', 'Fuchun Primary School', 'Corporation Primary School', 'Northshore Primary School', 'Xingnan Primary School', 'Lianhua Primary School', 'Ahmad Ibrahim Primary School', 'Anchor Green Primary School', 'Ang Mo Kio Primary School', 'Angsana Primary School', 'Beacon Primary School', 'Bedok Green Primary School', 'Bendemeer Primary School', 'Blangah Rise Primary School', 'Boon Lay Garden Primary School', 'Bukit View Primary School', 'Cantonment Primary School', 'Casuarina Primary School', 'Cedar Primary School', 'Changkat Primary School', 'Clementi Primary School', 'Damai Primary School', 'Dazhong Primary School', 'East Sp ...

# %% [markdown]
# ## Retrieve corresponding coordinates of primary school

# %%
def generate_OneMap_headers():
    """ generates new one map token """
    onemapKey = get_OneMap_token()
    headers = {"Authorization": onemapKey}
    return headers

def get_coordinates_from_location(location,headers):
    """returns number of results found, search value, and coordinates given a supplied location 
    Args:
        location (str): a location in singapore
    Returns:
        tuple: strings corresponding to number of results found, search value, lat, and lon
    """
    
    url = f"https://www.onemap.gov.sg/api/common/elastic/search?searchVal={location}&returnGeom=Y&getAddrDetails=Y&pageNum=1"
        
    response = requests.request("GET", url, headers=headers)
    response = response.json()
    response_first_result = response['results'][0] # get first item in the list
    return response_first_result

headers = generate_OneMap_headers()
searchVal = get_coordinates_from_location(school_names[0],headers=headers)
searchVal
# Out:
# {'SEARCHVAL': "PAYA LEBAR METHODIST GIRLS' SCHOOL (PRIMARY)",
#  'BLK_NO': '298',
#  'ROAD_NAME': 'LORONG AH SOO',
#  'BUILDING': "PAYA LEBAR METHODIST GIRLS' SCHOOL (PRIMARY)",
#  'ADDRESS': "298 LORONG AH SOO PAYA LEBAR METHODIST GIRLS' SCHOOL (PRIMARY) SINGAPORE 536741",
#  'POSTAL': '536741',
#  'X': '33748.3760953182',
#  'Y': '36843.4187818952',
#  'LATITUDE': '1.34947276268396',
#  'LONGITUDE': '103.884971343143'}

# %% [markdown]
# ## Convert to df

# %%
school_list = []
for s in school_names:
    searchVal = get_coordinates_from_location(s,headers=headers)
    searchVal['School Name'] = s
    school_list.append(searchVal)

school_df = pd.DataFrame(school_list)
school_df.head()
# Out:
#                                       SEARCHVAL BLK_NO             ROAD_NAME  \
# 0  PAYA LEBAR METHODIST GIRLS' SCHOOL (PRIMARY)    298         LORONG AH SOO
# 1                         FORMER TAO NAN SCHOOL     39       ARMENIAN STREET
# 2                                AI TONG SCHOOL    100     BRIGHT HILL DRIVE
# 3                HOLY INNOCENTS' PRIMARY SCHOOL      5       LORONG LOW KOON
# 4             CHIJ SAINT NICHOLAS GIRLS' SCHOOL    501  ANG MO KIO STREET 13
#
#                                        BUILDING  \
# 0  PAYA LEBAR METHODIST GIRLS' SCHOOL (PRIMARY)
# 1                         FORMER TAO NAN SCHOOL
# 2                                AI TONG SCHOOL
# 3                HOLY INNOCENTS' PRIMARY SCHOOL
# 4             CHIJ SAINT NICHOLAS GIRLS' SCHOOL
#
#                                              ADDRESS  POSTAL  \
# 0  298 LORONG AH SOO PAYA LEBAR METHODIST GIRLS' ...  536741
# 1  39 ARMENIAN STREET FORMER TAO NAN SCHOOL SINGA...  179941
# 2  100 BRIGHT HILL DRIVE AI TONG SCHOOL SINGAPORE...  579646
# 3  5 LORONG LOW KOON HOLY INNOCENTS' PRIMARY SCHO...  536451
# 4  501 ANG MO KIO STREET 13 CHIJ SAINT NICHOLAS G...  569405
#
#                   X                 Y          LATITUDE         LONGITUDE  \
# 0  33748.3760953182  36843.4187818952  1.34947276268396  103.884971343143
# 1   29748.116507777  30746.1923441123   1.2943321052493  103.849026157822
# 2  27966.8088298785  38071.9191181567   1.3605834338904  103.833020333986
# 3  34765.9036816582  38774.6943912152  1.36693830877349  103.894114899795
# 4  28104.0195931299  39497.6106162649  1.37347687878916  103.834253269436
#
#                          School Name
# 0  Methodist Girls' School (Primary)
# 1                     Tao Nan School
# 2                     Ai Tong School
# 3     Holy Innocents' Primary School
# 4    CHIJ St. Nicholas Girls' School

# %% [markdown]
# ### Get nodesID for school

# %%
school_df[['LONGITUDE','LATITUDE']] = school_df[['LONGITUDE','LATITUDE']].apply(pd.to_numeric, errors='coerce')
school_df['nodesID_school_car'] = ox.nearest_nodes(G_car,X=school_df['LONGITUDE'], Y=school_df['LATITUDE'])
school_df['nodesID_school_walk'] = ox.nearest_nodes(G_walk,X=school_df['LONGITUDE'], Y=school_df['LATITUDE'])

school_df.head()
# Out:
#                                       SEARCHVAL BLK_NO             ROAD_NAME  \
# 0  PAYA LEBAR METHODIST GIRLS' SCHOOL (PRIMARY)    298         LORONG AH SOO
# 1                         FORMER TAO NAN SCHOOL     39       ARMENIAN STREET
# 2                                AI TONG SCHOOL    100     BRIGHT HILL DRIVE
# 3                HOLY INNOCENTS' PRIMARY SCHOOL      5       LORONG LOW KOON
# 4             CHIJ SAINT NICHOLAS GIRLS' SCHOOL    501  ANG MO KIO STREET 13
#
#                                        BUILDING  \
# 0  PAYA LEBAR METHODIST GIRLS' SCHOOL (PRIMARY)
# 1                         FORMER TAO NAN SCHOOL
# 2                                AI TONG SCHOOL
# 3                HOLY INNOCENTS' PRIMARY SCHOOL
# 4             CHIJ SAINT NICHOLAS GIRLS' SCHOOL
#
#                                              ADDRESS  POSTAL  \
# 0  298 LORONG AH SOO PAYA LEBAR METHODIST GIRLS' ...  536741
# 1  39 ARMENIAN STREET FORMER TAO NAN SCHOOL SINGA...  179941
# 2  100 BRIGHT HILL DRIVE AI TONG SCHOOL SINGAPORE...  579646
# 3  5 LORONG LOW KOON HOLY INNOCENTS' PRIMARY SCHO...  536451
# 4  501 ANG MO KIO STREET 13 CHIJ SAINT NICHOLAS G...  569405
#
#                   X                 Y  LATITUDE   LONGITUDE  \
# 0  33748.3760953182  36843.4187818952  1.349473  103.884971
# 1   29748.116507777  30746.1923441123  1.294332  103.849026
# 2  27966.8088298785  38071.9191181567  1.360583  103.833020
# 3  34765.9036816582  38774.6943912152  1.366938  103.894115
# 4  28104.0195931299  39497.6106162649  1.373477  103.834253
#
#                          School Name  nodesID_school_car  nodesID_school_walk
# 0  Methodist Girls' School (Primary)           366226693            366226693
# 1                     Tao Nan School          7152969482           6673357533
# 2                     Ai Tong School          4598816959           5270039725
# 3     Holy Innocents' Primary School          2959762943           5214893587
# 4    CHIJ St. Nicholas Girls' School          5809936563           8079538307

# %% [markdown]
# ### Export as csv

# %%
school_df.to_csv(os.path.join(os.getcwd(),"Data","topPrimarySchools.csv"),index=False)
